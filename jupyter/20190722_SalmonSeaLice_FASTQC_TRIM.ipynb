# %%
#copy data from Globus to gannet

# %%
mkdir /Volumes/web/metacarcinus/Salmo_Calig/FASTQS

# %%
#see markdown post about how data was transfered from Sequencing core to Gannet

# %%
#copy compressed directory to mox

# %%
#untar files 
#tar -xvf UW_Trigg_190718.tar.gz

# %%
# !ls /Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/
# Out:
# 16C_26psu_1_S13_L001_R1_001.fastq.gz
# 16C_26psu_1_S13_L001_R2_001.fastq.gz
# 16C_26psu_1_S13_L002_R1_001.fastq.gz
# 16C_26psu_1_S13_L002_R2_001.fastq.gz
# 16C_26psu_2_S14_L001_R1_001.fastq.gz
# 16C_26psu_2_S14_L001_R2_001.fastq.gz
# 16C_26psu_2_S14_L002_R1_001.fastq.gz
# 16C_26psu_2_S14_L002_R2_001.fastq.gz
# 16C_26psu_3_S15_L001_R1_001.fastq.gz
# 16C_26psu_3_S15_L001_R2_001.fastq.gz
# 16C_26psu_3_S15_L002_R1_001.fastq.gz
# 16C_26psu_3_S15_L002_R2_001.fastq.gz
# 16C_26psu_4_S16_L001_R1_001.fastq.gz
# 16C_26psu_4_S16_L001_R2_001.fastq.gz
# 16C_26psu_4_S16_L002_R1_001.fastq.gz
# 16C_26psu_4_S16_L002_R2_001.fastq.gz
# 16C_32psu_1_S1_L001_R1_001.fastq.gz
# 16C_32psu_1_S1_L001_R2_001.fastq.gz
# 16C_32psu_1_S1_L002_R1_001.fastq.gz
# 16C_32psu_1_S1_L002_R2_001.fastq.gz
# 16C_32psu_2_S2_L001_R1_001.fastq.gz
# 16C_32psu_2_S2_L001_R2_001.fastq.gz
# 16C_32psu_2_S2_L002_R1_001.fastq.gz
# 16C_32psu_2_S2_L002_R2_001.fastq.gz
# 16C_32psu_3_S3_L001_R1_001.fastq.gz
# ...

# %%
#run fastqc

# %%
# !/Users/Shared/bioinformatics/FastQC/fastqc \
--outdir /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722 \
--threads 4 \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_2_S14_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_2_S14_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_2_S14_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_2_S14_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_3_S15_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_3_S15_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_3_S15_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_3_S15_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_4_S16_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_4_S16_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_4_S16_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_4_S16_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_1_S1_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_1_S1_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_1_S1_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_1_S1_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_2_S2_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_2_S2_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_2_S2_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_2_S2_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_3_S3_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_3_S3_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_3_S3_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_3_S3_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_4_S4_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_4_S4_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_4_S4_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_4_S4_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_1_S9_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_1_S9_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_1_S9_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_1_S9_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_2_S10_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_2_S10_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_2_S10_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_2_S10_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_3_S11_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_3_S11_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_3_S11_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_3_S11_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_4_S12_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_4_S12_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_4_S12_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_4_S12_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_1_S5_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_1_S5_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_1_S5_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_1_S5_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_2_S6_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_2_S6_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_2_S6_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_2_S6_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_3_S7_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_3_S7_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_3_S7_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_3_S7_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_4_S8_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_4_S8_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_4_S8_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_4_S8_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_1_S19_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_1_S19_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_1_S19_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_1_S19_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_2_S21_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_2_S21_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_2_S21_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_2_S21_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_1_S17_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_1_S17_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_1_S17_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_1_S17_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_2_S18_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_2_S18_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_2_S18_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_2_S18_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F1_S20_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F1_S20_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F1_S20_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F1_S20_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F2_S22_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F2_S22_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F2_S22_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F2_S22_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Undetermined_S0_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Undetermined_S0_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Undetermined_S0_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Undetermined_S0_L002_R2_001.fastq.gz
# Out:
# Started analysis of 16C_26psu_1_S13_L001_R1_001.fastq.gz
# Started analysis of 16C_26psu_1_S13_L001_R2_001.fastq.gz
# Started analysis of 16C_26psu_1_S13_L002_R1_001.fastq.gz
# Started analysis of 16C_26psu_1_S13_L002_R2_001.fastq.gz
# Approx 5% complete for 16C_26psu_1_S13_L001_R1_001.fastq.gz
# Approx 5% complete for 16C_26psu_1_S13_L001_R2_001.fastq.gz
# Approx 5% complete for 16C_26psu_1_S13_L002_R1_001.fastq.gz
# Approx 5% complete for 16C_26psu_1_S13_L002_R2_001.fastq.gz
# Approx 10% complete for 16C_26psu_1_S13_L001_R1_001.fastq.gz
# Approx 10% complete for 16C_26psu_1_S13_L001_R2_001.fastq.gz
# Approx 10% complete for 16C_26psu_1_S13_L002_R1_001.fastq.gz
# Approx 10% complete for 16C_26psu_1_S13_L002_R2_001.fastq.gz
# Approx 15% complete for 16C_26psu_1_S13_L001_R1_001.fastq.gz
# Approx 15% complete for 16C_26psu_1_S13_L002_R2_001.fastq.gz
# Approx 15% complete for 16C_26psu_1_S13_L001_R2_001.fastq.gz
# Approx 15% complete for 16C_26psu_1_S13_L002_R1_001.fastq.gz
# ...

# %%
#run multiqc

# %%
# !cd /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722
# !/Users/strigg/anaconda3/bin/multiqc .
# Out:
# /Users/strigg/anaconda3/lib/python3.6/site-packages/multiqc-1.0.dev0-py3.6.egg/multiqc/utils/config.py:44: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   configs = yaml.load(f)
# /Users/strigg/anaconda3/lib/python3.6/site-packages/multiqc-1.0.dev0-py3.6.egg/multiqc/utils/config.py:50: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   sp = yaml.load(f)
# [WARNING]         multiqc : MultiQC Version v1.7 now available!
# [INFO   ]         multiqc : This is MultiQC v1.0.dev0
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/16C_26psu_1_S13_L001_R1_001_fastqc.html'
# ...

# %%
#make new directory for trim output

# %%
# !mkdir /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt
# !mkdir /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt/FASTQC
# Out:
# mkdir: /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt: File exists
# mkdir: /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt/FASTQC: File exists

# %%
#trim adapters off reads

# %%
# !/Users/strigg/anaconda3/bin/TrimGalore-0.6.0/trim_galore \
--output_dir /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt \
--fastqc_args \
"--outdir /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt/FASTQC" \
--illumina \
--path_to_cutadapt /Users/strigg/anaconda3/bin/cutadapt \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_2_S14_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_2_S14_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_2_S14_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_2_S14_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_3_S15_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_3_S15_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_3_S15_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_3_S15_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_4_S16_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_4_S16_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_4_S16_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_4_S16_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_1_S1_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_1_S1_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_1_S1_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_1_S1_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_2_S2_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_2_S2_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_2_S2_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_2_S2_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_3_S3_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_3_S3_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_3_S3_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_3_S3_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_4_S4_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_4_S4_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_4_S4_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_32psu_4_S4_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_1_S9_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_1_S9_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_1_S9_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_1_S9_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_2_S10_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_2_S10_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_2_S10_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_2_S10_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_3_S11_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_3_S11_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_3_S11_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_3_S11_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_4_S12_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_4_S12_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_4_S12_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_26psu_4_S12_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_1_S5_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_1_S5_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_1_S5_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_1_S5_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_2_S6_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_2_S6_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_2_S6_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_2_S6_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_3_S7_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_3_S7_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_3_S7_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_3_S7_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_4_S8_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_4_S8_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_4_S8_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/8C_32psu_4_S8_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_1_S19_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_1_S19_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_1_S19_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_1_S19_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_2_S21_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_2_S21_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_2_S21_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_16C_26psu_2_S21_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_1_S17_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_1_S17_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_1_S17_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_1_S17_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_2_S18_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_2_S18_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_2_S18_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/CTRL_8C_26psu_2_S18_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F1_S20_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F1_S20_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F1_S20_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F1_S20_L002_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F2_S22_L001_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F2_S22_L001_R2_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F2_S22_L002_R1_001.fastq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/Sealice_F2_S22_L002_R2_001.fastq.gz
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: '/Users/strigg/anaconda3/bin/cutadapt' (user defined)
# Cutadapt seems to be working fine (tested command '/Users/strigg/anaconda3/bin/cutadapt --version')
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt/
# gzip: error writing to output: Broken pipe
# gzip: /Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L001_R1_001.fastq.gz: uncompress failed
# Writing report to '/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt/16C_26psu_1_S13_L001_R1_001.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ...
# Input filename: /Volumes/web/metacarcinus/Salmo_Calig/FASTQS/UW_Trigg_190718_done/16C_26psu_1_S13_L001_R1_001.fastq.gz
# Trimming mode: single-end
# ...

# %%
#run multiqc of trimmed reads

# %%
# !cd /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt/FASTQC
# !/Users/strigg/anaconda3/bin/multiqc .
# Out:
# /Users/strigg/anaconda3/lib/python3.6/site-packages/multiqc-1.0.dev0-py3.6.egg/multiqc/utils/config.py:44: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   configs = yaml.load(f)
# /Users/strigg/anaconda3/lib/python3.6/site-packages/multiqc-1.0.dev0-py3.6.egg/multiqc/utils/config.py:50: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   sp = yaml.load(f)
# [WARNING]         multiqc : MultiQC Version v1.7 now available!
# [INFO   ]         multiqc : This is MultiQC v1.0.dev0
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# ##### ERROR! MatPlotLib library could not be loaded!    #####
# ##### Flat plots will instead be plotted as interactive #####
# [ERROR  ]        bargraph : cannot import name 'get_backend'
# ...

# %%
#trim first 5 bases from each read ended up runnin

# %%
# !mkdir /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp
# !mkdir /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/FASTQC
# Out:
# mkdir: /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp: File exists
# mkdir: /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/FASTQC: File exists

# %%
#ended up running this on Mox with this code: /gscratch/srlab/strigg/jobs/20190725_Trim1st5bp.sh
# also I couldn't figure out how to get this loop to work because xargs sh -c expects 
## commands in '' and awk introduces another set of ''. I found a work around here:
## https://unix.stackexchange.com/questions/282503/right-syntax-for-awk-usage-in-combination-with-other-command-inside-xargs-sh-c
## but had a problem when including the redirect
#maybe some day I'll learn to code better!
####  !find /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt/*R1_001_trimmed.fq.gz \
#### | xargs basename -s _L001_R1_001_trimmed.fq.gz | xargs -I{} sh -c \
#### 'gzcat /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_adapt/{}_L001_R1_001_trimmed.fq.gz;awk '\''{if(($1 !~ /^@A00177\:/) && ($1 !~ /^\+$/))print substr($1,6,length($1));else print $1}'\'';gzip > /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/{}_L001_R1_001_trimmed.5bp_3prime.fq.gz'

# %%
#run fastqc on trimmed 1st 5bp + adapter trimmed reads

# %%
# !/Users/Shared/bioinformatics/FastQC/fastqc \
--outdir /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/FASTQC \
--threads 4 \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_1_S13_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_1_S13_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_1_S13_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_1_S13_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_2_S14_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_2_S14_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_2_S14_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_2_S14_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_3_S15_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_3_S15_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_3_S15_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_3_S15_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_4_S16_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_4_S16_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_4_S16_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_26psu_4_S16_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_1_S1_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_1_S1_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_1_S1_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_1_S1_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_2_S2_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_2_S2_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_2_S2_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_2_S2_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_3_S3_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_3_S3_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_3_S3_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_3_S3_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_4_S4_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_4_S4_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_4_S4_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/16C_32psu_4_S4_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_1_S9_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_1_S9_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_1_S9_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_1_S9_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_2_S10_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_2_S10_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_2_S10_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_2_S10_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_3_S11_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_3_S11_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_3_S11_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_3_S11_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_4_S12_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_4_S12_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_4_S12_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_26psu_4_S12_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_1_S5_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_1_S5_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_1_S5_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_1_S5_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_2_S6_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_2_S6_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_2_S6_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_2_S6_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_3_S7_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_3_S7_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_3_S7_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_3_S7_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_4_S8_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_4_S8_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_4_S8_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/8C_32psu_4_S8_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_16C_26psu_1_S19_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_16C_26psu_1_S19_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_16C_26psu_1_S19_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_16C_26psu_1_S19_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_16C_26psu_2_S21_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_16C_26psu_2_S21_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_16C_26psu_2_S21_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_16C_26psu_2_S21_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_8C_26psu_1_S17_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_8C_26psu_1_S17_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_8C_26psu_1_S17_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_8C_26psu_1_S17_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_8C_26psu_2_S18_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_8C_26psu_2_S18_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_8C_26psu_2_S18_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/CTRL_8C_26psu_2_S18_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/Sealice_F1_S20_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/Sealice_F1_S20_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/Sealice_F1_S20_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/Sealice_F1_S20_L002_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/Sealice_F2_S22_L001_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/Sealice_F2_S22_L001_R2_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/Sealice_F2_S22_L002_R1_001_trimmed.5bp_3prime.fq.gz \
/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/Sealice_F2_S22_L002_R2_001_trimmed.5bp_3prime.fq.gz
# Out:
# Started analysis of 16C_26psu_1_S13_L001_R1_001_trimmed.5bp_3prime.fq.gz
# Started analysis of 16C_26psu_1_S13_L001_R2_001_trimmed.5bp_3prime.fq.gz
# Started analysis of 16C_26psu_1_S13_L002_R1_001_trimmed.5bp_3prime.fq.gz
# Started analysis of 16C_26psu_1_S13_L002_R2_001_trimmed.5bp_3prime.fq.gz
# Approx 5% complete for 16C_26psu_1_S13_L001_R2_001_trimmed.5bp_3prime.fq.gz
# Approx 5% complete for 16C_26psu_1_S13_L001_R1_001_trimmed.5bp_3prime.fq.gz
# Approx 5% complete for 16C_26psu_1_S13_L002_R2_001_trimmed.5bp_3prime.fq.gz
# Approx 5% complete for 16C_26psu_1_S13_L002_R1_001_trimmed.5bp_3prime.fq.gz
# Approx 10% complete for 16C_26psu_1_S13_L001_R1_001_trimmed.5bp_3prime.fq.gz
# Approx 10% complete for 16C_26psu_1_S13_L002_R2_001_trimmed.5bp_3prime.fq.gz
# Approx 10% complete for 16C_26psu_1_S13_L001_R2_001_trimmed.5bp_3prime.fq.gz
# Approx 10% complete for 16C_26psu_1_S13_L002_R1_001_trimmed.5bp_3prime.fq.gz
# ...

# %%
#run multiqc on adapter + 1st5bp trimmed data; did this on emu and copied back over to Gannet:
# /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/FASTQC/multiqc_data

# %%
#concatenate L001 and L002 fastqs; cat just appends files so no unzipping necessary
# for concatenating fastqs, see here:
#for xargs command use, see here: https://stackoverflow.com/questions/845863/how-to-use-in-an-xargs-command
# ran this job on mox (https://gannet.fish.washington.edu/metacarcinus/mox_jobs/20190805_Concat_L1_L2_SalmoCalig.sh)

##%%bash 

##find /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/*_L001_R1_001_trimmed.5bp_3prime.fq.gz \
##| xargs basename -s _L001_R1_001_trimmed.5bp_3prime.fq.gz | xargs -I {} sh -c 'cat \
##"/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/$1_L001_R1_001_trimmed.5bp_3prime.fq.gz" \
##"/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/$1_L002_R1_001_trimmed.5bp_3prime.fq.gz" \
##> "/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_cat/$1_R1_001_trimmed.5bp_3prime.fq.gz"' -- {}

##%%bash 

##find /Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/*_L001_R2_001_trimmed.5bp_3prime.fq.gz \
##| xargs basename -s _L001_R2_001_trimmed.5bp_3prime.fq.gz | xargs -I {} sh -c 'cat \
##"/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/$1_L001_R2_001_trimmed.5bp_3prime.fq.gz" \
###"/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_1st5bp/$1_L002_R2_001_trimmed.5bp_3prime.fq.gz" \
##> "/Volumes/web/metacarcinus/Salmo_Calig/analyses/20190722/TRIM_cat/$1_R2_001_trimmed.5bp_3prime.fq.gz"' -- {}

# %%
## ran test alignment on mox using adapter trimmed and adapter trimmed + 5bp trimmed reads, but had very poor alignment
## attempting to follow these notes: https://sequencing.qcfail.com/articles/mispriming-in-pbat-libraries-causes-methylation-bias-and-poor-mapping-efficiencies/
## to improve mapping

# %%
# !/Users/strigg/anaconda3/bin/TrimGalore-0.6.0/trim_galore \
--output_dir /Users/strigg/Desktop/Salmo_Calig/TRIM \
--fastqc_args \
"--outdir /Users/strigg/Desktop/Salmo_Calig/TRIM/FASTQC" \
--clip_R1 5 \
--clip_R2 5 \
--paired \
--path_to_cutadapt /Users/strigg/anaconda3/bin/cutadapt \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_2_S14_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_2_S14_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_2_S14_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_2_S14_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_3_S15_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_3_S15_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_3_S15_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_3_S15_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_4_S16_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_4_S16_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_4_S16_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_4_S16_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_1_S1_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_1_S1_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_1_S1_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_1_S1_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_2_S2_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_2_S2_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_2_S2_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_2_S2_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_3_S3_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_3_S3_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_3_S3_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_3_S3_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_4_S4_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_4_S4_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_4_S4_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_32psu_4_S4_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_1_S9_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_1_S9_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_1_S9_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_1_S9_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_2_S10_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_2_S10_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_2_S10_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_2_S10_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_3_S11_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_3_S11_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_3_S11_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_3_S11_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_4_S12_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_4_S12_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_4_S12_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_26psu_4_S12_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_1_S5_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_1_S5_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_1_S5_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_1_S5_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_2_S6_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_2_S6_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_2_S6_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_2_S6_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_3_S7_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_3_S7_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_3_S7_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_3_S7_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_4_S8_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_4_S8_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_4_S8_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/8C_32psu_4_S8_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_16C_26psu_1_S19_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_16C_26psu_1_S19_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_16C_26psu_1_S19_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_16C_26psu_1_S19_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_16C_26psu_2_S21_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_16C_26psu_2_S21_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_16C_26psu_2_S21_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_16C_26psu_2_S21_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_8C_26psu_1_S17_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_8C_26psu_1_S17_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_8C_26psu_1_S17_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_8C_26psu_1_S17_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_8C_26psu_2_S18_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_8C_26psu_2_S18_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_8C_26psu_2_S18_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/CTRL_8C_26psu_2_S18_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/Sealice_F1_S20_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/Sealice_F1_S20_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/Sealice_F1_S20_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/Sealice_F1_S20_L002_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/Sealice_F2_S22_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/Sealice_F2_S22_L001_R2_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/Sealice_F2_S22_L002_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/Sealice_F2_S22_L002_R2_001.fastq.gz
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: '/Users/strigg/anaconda3/bin/cutadapt' (user defined)
# Cutadapt seems to be working fine (tested command '/Users/strigg/anaconda3/bin/cutadapt --version')
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /Users/strigg/Desktop/Salmo_Calig/TRIM/
# gzip: error writing to output: Broken pipe
# gzip: /Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L001_R1_001.fastq.gz: uncompress failed
#
#
# AUTO-DETECTING ADAPTER TYPE
# ...
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L001_R1_001.fastq.gz <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	538094	AGATCGGAAGAGC	1000000	53.81
# ...

# %%
#Run a test to see % reads retained when 'retain unpaired' option is used

# %%
# !/Users/strigg/anaconda3/bin/TrimGalore-0.6.0/trim_galore \
--output_dir /Users/strigg/Desktop/Salmo_Calig/TRIM/retained \
--fastqc_args \
"--outdir /Users/strigg/Desktop/Salmo_Calig/TRIM/retained/FASTQC" \
--clip_R1 5 \
--clip_R2 5 \
--paired \
--retain_unpaired \
--path_to_cutadapt /Users/strigg/anaconda3/bin/cutadapt \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L001_R1_001.fastq.gz \
/Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L001_R2_001.fastq.gz
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: '/Users/strigg/anaconda3/bin/cutadapt' (user defined)
# Cutadapt seems to be working fine (tested command '/Users/strigg/anaconda3/bin/cutadapt --version')
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /Users/strigg/Desktop/Salmo_Calig/TRIM/retained/
# gzip: error writing to output: Broken pipe
# gzip: /Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L001_R1_001.fastq.gz: uncompress failed
#
#
# AUTO-DETECTING ADAPTER TYPE
# ...
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /Users/strigg/Desktop/Salmo_Calig/16C_26psu_1_S13_L001_R1_001.fastq.gz <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	538094	AGATCGGAAGAGC	1000000	53.81
# ...
